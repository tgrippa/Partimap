# %% [markdown]
# # **Predicting the perception of deprivation from VHR Satelite Images.**

# %% [markdown]
# # Intro

# %% [markdown]
# This code is developed by [**Taïs Grippa**](https://github.com/tgrippa) for the **PARTIMAP** project, based on the initial code of [**Eqi Luo**](https://github.com/EqiLuo/MappingDeprivation).

# %% [markdown]
# # 0. Import libraries
#
# Firstly, install and import the necessary libraries for this analysis.

# %%
import numpy as np
import os, sys
import pandas as pd
import glob
import re
from tensorflow import keras
import natsort
import sklearn
import tensorflow as tf
import datetime
import cv2
import shutil
import time
import tempfile
import h5py

# %%
from IPython.display import clear_output

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from osgeo import gdal
from osgeo import gdal_array
from natsort import natsorted
from keras.utils import np_utils
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Input
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator
#from keras import backend as K

# %% [markdown]
# Check the version of Tensorflow. It should be 2.8.0

# %%
print(tf.__version__)
# Out:
# 2.8.0

# %% [markdown]
# Check the output of nvidia-smi utility to monitor the GPU usage.

# %%
! nvidia-smi
# Out:
# Wed Mar 16 17:08:48 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 510.47.03    Driver Version: 510.47.03    CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:01:00.0 Off |                  N/A |
# | 23%   33C    P0    53W / 250W |      0MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA GeForce ...  Off  | 00000000:02:00.0 Off |                  N/A |
# | 11%   33C    P0    38W / 250W |      0MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# Configure Tensorflow (v2.8) for deterministic behavior (to get reproducible results). See official manual [HERE](https://www.tensorflow.org/api_docs/python/tf/config/experimental/enable_op_determinism). NOTICE: Has never worked properly :/

# %%
import random as python_random
SEED = 101
np.random.seed(SEED)
python_random.seed(SEED)
tf.random.set_seed(SEED)
tf.config.experimental.enable_op_determinism()

# %% [markdown]
# Import Keras Tuner for Hyperparameter tuning

# %%
import keras_tuner as kt
from keras_tuner import HyperModel

# %% [markdown]
# Setup Keras to work with Mixed Precision to speed up the learning process and reduce GPU memory required. More information [HERE](https://keras.io/api/mixed_precision/).

# %%
# Setup Keras Mixed Precision
tf.keras.mixed_precision.set_global_policy("mixed_float16")
# Out:
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPUs will likely run quickly with dtype policy mixed_float16 as they all have compute capability of at least 7.0

# %% [markdown]
# Import custom functions

# %%
# Add local module to the path
src = os.path.abspath('../SRC')
if src not in sys.path:
    sys.path.append(src)

# %%
# Import functions for processing time information
from processing_time import start_processing, print_processing_time
# Import function that checks and creates folder
from mkdir import check_create_dir
# Import functions for plots
from plots import plot_loss, plot_pred_test, plot_pred_train, plot_loss_multirun
# Import functions for metrics to monitoring accuracy
from metrics import coeff_determination
# Import functions for display
from display import Norma_Xpercentile
# Import functions for exportation of results
from export_results import save_predictions, write_run_metrics_file
# Import LRFinder function
from LRFinder import LRFinder

# %% [markdown]
# Test is GPU(s) is(are) available for processing and measure the speed-up of using it(them).

# %%
# %run ../SRC/Check_GPU_available.py
# Out:
# 2 Physical GPUs, 2 Logical GPUs
# Time (s) to convolve 32x7x7x3 filter over random 100x100x100x3 images (batch x height x width x channel). Sum of ten runs.
# CPU (s):
# 1.1298230672255158
# GPU (s):
# 0.034228252712637186
# GPU speedup over CPU: 33x

# %% [markdown]
# # 1. Data preparation
#
# **In this part, we load the data prepared before.**

# %%
# Set ID of experiment
experiment_id = 25

# %%
# Define working path 
root = "/home/tgrippa/PARTIMAP_processing"
#data_path = os.path.join(root, "data_p3_outliers_7030")
#data_path = os.path.join(root, "data_p3_outliers_8020")
#data_path = os.path.join(root, "data_p3_outliers_9010")
data_path = os.path.join(root, "data_p3_outliers_kfold10")
output_path = os.path.join(root, "output_VGG_exp_%s" %experiment_id)
model_path = os.path.join(output_path, "model")
results_path = os.path.join(output_path, "results")

# %%
#Check and create output data directory if needed
list_directories = [output_path, model_path, results_path, data_path]
for path in list_directories:
    check_create_dir(path)
# Out:
# The folder '/home/tgrippa/PARTIMAP_processing/output_VGG_exp_25' already exists
# The folder '/home/tgrippa/PARTIMAP_processing/output_VGG_exp_25/model' already exists
# The folder '/home/tgrippa/PARTIMAP_processing/output_VGG_exp_25/results' already exists
# The folder '/home/tgrippa/PARTIMAP_processing/data_p3_outliers_kfold10' already exists

# %%
# Read the dataset from HDF5 file
idx_train = []
idx_val = []
with h5py.File(os.path.join(data_path,"VNIR_128.hdf5"), mode="r") as f:
    stack = np.asarray(f["stack"])
    scores = np.asarray(f["scores"])
    photo_id = np.asarray(f["photo_id"])
    for i in f['idx_train'].keys():      
        idx_train.append(np.asarray(f['idx_train'][i]))
    for i in f['idx_val'].keys():      
        idx_val.append(np.asarray(f['idx_val'][i]))

# %%
# Check the shape of each sub-dataset 
fold = 1
for t,v in zip(idx_train,idx_val):
    print("----- Fold %s -----" %fold)
    print("Train %s   Val %s" %(t.shape,v.shape))    
    fold += 1
# Out:
# ----- Fold 1 -----
# Train (1798,)   Val (200,)
# ----- Fold 2 -----
# Train (1798,)   Val (200,)
# ----- Fold 3 -----
# Train (1798,)   Val (200,)
# ----- Fold 4 -----
# Train (1798,)   Val (200,)
# ----- Fold 5 -----
# Train (1798,)   Val (200,)
# ----- Fold 6 -----
# Train (1798,)   Val (200,)
# ----- Fold 7 -----
# Train (1798,)   Val (200,)
# ----- Fold 8 -----
# Train (1798,)   Val (200,)
# ----- Fold 9 -----
# Train (1799,)   Val (199,)
# ----- Fold 10 -----
# Train (1799,)   Val (199,)

# %%
# Random selection
plt.rcParams["figure.facecolor"] = 'w'
plt.figure(figsize=(15, 15))
for i in range(3):
    rd_img = np.random.randint(1,500)
    ax = plt.subplot(1, 3, i + 1)
    plt.imshow(Norma_Xpercentile(stack[rd_img,:,:,:]))
    plt.axis("off")
    plt.title("Random indx: %s\nPARTIMAP ID: %s\nTrueSkill-score: %0.3f" %(rd_img,photo_id[rd_img],scores[rd_img]))
#plt.subplots_adjust(hspace=0.001)
plt.tight_layout()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # 2 Model definition
# Here, we train a VGG-like model to predict the deprivation degree.
# The architecture of the model has been design under a trial-and-error approach.
# Since Tensorflow is difficult to configure to avoid stochiastic behaviour [(Alahmari et al. 2020)](https://ieeexplore.ieee.org/document/9266043/), the implement a multiple run approach.

# %% [markdown]
# ## 2.1 Data augmentation layers

# %% [markdown]
# #### **Data augmentation definition**

# %%
# Define data augmentation to be included at the top of the sequential model 
data_augmentation = tf.keras.Sequential([
                        layers.RandomFlip("vertical"),
                        layers.RandomRotation(0.2, fill_mode='reflect'),
                        layers.RandomTranslation(height_factor=0.05, width_factor=0.05, fill_mode='reflect'),
                    ])

# %% [markdown]
# ## 2.2 VGG model definition

# %%
# Input shape 
input_shape = (224, 224, 3)

# %%
## VGG-like regression model with hyperparameter tuning

def VGG_model():
    model = Sequential()
    
    # Data augmentation
    model.add(data_augmentation)
    
    # Convolution block 1 
    model.add(Conv2D(32, (3, 3), padding='same', name='block1_conv1', input_shape=input_shape)) #block1_conv1
    model.add(BatchNormalization(axis=-1, name='block1_bn1'))
    model.add(Activation('relu'))
    model.add(Conv2D(32, (3, 3), padding='same', name='block1_conv2')) #block1_conv2 
    model.add(BatchNormalization(axis=-1, name='block1_bn2'))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), name='block1_pool')) #block1_pool
    
    # Convolution block 2 
    model.add(Conv2D(64, (3, 3), padding='same', name='block2_conv1')) #block2_conv1
    model.add(BatchNormalization(axis=-1, name='block2_bn1'))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (3, 3), padding='same', name='block2_conv2')) #block2_conv2
    model.add(BatchNormalization(axis=-1, name='block2_bn2'))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), name='block2_pool')) #block2_pool
    
    # Convolution block 3 
    model.add(Conv2D(128, (3, 3), padding='same', name='block3_conv1')) #block3_conv1
    model.add(BatchNormalization(axis=-1, name = 'block3_bn1'))
    model.add(Activation('relu'))
    model.add(Conv2D(128, (3, 3), padding='same', name='block3_conv2')) #block3_conv2
    model.add(BatchNormalization(axis=-1, name='block3_bn2'))
    model.add(Activation('relu'))
    model.add(Conv2D(128, (3, 3), padding='same', name='block3_conv3')) #block3_conv3
    model.add(BatchNormalization(axis=-1, name='block3_bn3'))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), name='block3_pool')) #block3_pool

    # Convolution block 4 
#    model.add(Conv2D(256, (3, 3), padding='same', name='block4_conv1')) #block3_conv1
#    model.add(BatchNormalization(axis=-1, name = 'block4_bn1'))
#    model.add(Activation('relu'))
#    model.add(Conv2D(256, (3, 3), padding='same', name='block4_conv2')) #block3_conv2
#    model.add(BatchNormalization(axis=-1, name='block4_bn2'))
#    model.add(Activation('relu'))
#    model.add(Conv2D(256, (3, 3), padding='same', name='block4_conv3')) #block3_conv3
#    model.add(BatchNormalization(axis=-1, name='block4_bn3'))
#    model.add(Activation('relu'))
#    model.add(MaxPooling2D(pool_size=(2, 2), name='block4_pool')) #block3_pool
   
    # Now to configure the fully connected layers 
    
    # FC1
    model.add(Flatten())
    model.add(Dense(256, name = 'fc1'))
    model.add(BatchNormalization(axis=-1, name = 'fc1_bn1'))
    model.add(Activation('relu'))
    model.add(Dropout(0.4, name = 'fc1_drop', seed=3)) 

    # FC2
    model.add(Dense(256, name = 'fc2'))
    model.add(BatchNormalization(axis=-1, name = 'fc2_bn1'))
    model.add(Activation('relu'))
    model.add(Dropout(0.4, name = 'fc2_drop', seed=3))

    # Regression layer 
    model.add(Dense(1, activation = 'linear', name = 'regression'))   
    
    return model

# %%
class mutli_run():
    
    def __init__(self, nbrun, lr, earlypatience, reduceplateau, bsize, nb_epochs, datagen, outputfolder):
        self.nbrun = nbrun
        self.lr = lr
        self.earlypatience = earlypatience
        self.reduceplateau = reduceplateau
        self.bsize = bsize
        self.nb_epochs = nb_epochs
        self.datagen = datagen
        self.outputfolder = outputfolder

    def run(self):        
        # Save current time for time management
        starttime = start_processing()
        # Create folder for the multirun 
        check_create_dir(self.outputfolder)
        # Create a table (pandas dataframe) to store the multiple run values
        mutlirun_table = pd.DataFrame(columns = ["Run", "Run_dir", "Weight_file", "RunTime", "Epochs", "R2_train", "rmse_train", "mae_train", "R2_test", "rmse_test", "mae_test"],dtype=object)
        # Create a list of history
        multirun_histories = []
        self.multirun_histories = multirun_histories
        # Create a MirroredStrategy.
        strategy = tf.distribute.MirroredStrategy()
        print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
        
        for i in range(1,self.nbrun+1):    
            # Clear session to avoid increasing the memory usage after each loop
            tf.keras.backend.clear_session()
            # Clear the output of the previous loop
            clear_output(wait=True)
            # Print current loop number
            print("\nStarting run {}/{}...".format(i,self.nbrun))
            # Save current time for time management
            starttime = time.time()
            # Open a strategy scope.
            with strategy.scope():
                # Create a new instance of the model
                model = VGG_model()
                # Optimizer and learning rate    
                opt = Adam(learning_rate=self.lr)
                # Compile the model with LOSS, Optimizer, metrics
                model.compile(loss="mean_squared_error", optimizer=opt, metrics=['mean_absolute_error','RootMeanSquaredError',coeff_determination]) 

            # Define callbacks for this run (needed to reinitialise at least the checkpoint from the previous run)
            checkpoint_filepath = os.path.join(tempfile.mkdtemp(),'Best_performed_model.hdf5')
            checkpoint = ModelCheckpoint(checkpoint_filepath, monitor='val_mean_absolute_error', verbose=1, save_best_only=True, mode='min')
            tmp_csv_path = os.path.join(tempfile.gettempdir(), "run_log.csv")
            csv_logger = tf.keras.callbacks.CSVLogger(tmp_csv_path, separator=";", append=True)
            callbacklist = [checkpoint, csv_logger]
            if self.reduceplateau:
                reduce = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=self.reduceplateau, verbose=1, mode='auto', cooldown=0, min_lr=0)
                callbacklist.append(reduce)
            if self.earlypatience:
                early = EarlyStopping(monitor="val_loss",mode="min",patience=self.earlypatience) # probably needs to be more patient
                callbacklist.append(early)                
        
            # Train the model 
            history = model.fit(self.datagen.flow(x_train, y_train, batch_size=self.bsize, shuffle=False, seed=3),
                                steps_per_epoch=int(len(x_train)/self.bsize),
                                validation_data = (x_test,y_test),
                                epochs = self.nb_epochs, 
                                callbacks = callbacklist
                                )
            # Save processing time
            training_time = round((time.time() - starttime)/60,1)
            
            # Append the run history to the multirun_hostories list
            multirun_histories.append(history)
            
            # Load the weights from the best checkpoint
            model.load_weights(checkpoint_filepath)
            # run the model on the train and test datasets 
            y_pred_test = model.predict(x_test) 
            y_pred_train = model.predict(x_train)

            # Calculate the R2 Score and RMSE
            R2_train = r2_score(y_train, y_pred_train)
            rmse_train = mean_squared_error(y_train, y_pred_train,squared=False) 
            mae_train = mean_absolute_error(y_train, y_pred_train)
            R2_test = r2_score(y_test,y_pred_test)
            rmse_test = mean_squared_error(y_test, y_pred_test,squared=False) 
            mae_test = mean_absolute_error(y_test, y_pred_test) 

            # Create folder for this run 
            base_name = "val_%0.2f_test_%0.2f" %(R2_train,R2_test)
            runfolder = os.path.join(self.outputfolder, base_name)
            check_create_dir(runfolder)

            # Move tmp LOGGER files to run directory
            shutil.move(tmp_csv_path, os.path.join(runfolder, "run_log.txt"))
            
            # Write metrics on the run log file
            log_path = os.path.join(runfolder, "run_metrics_%s.txt" %base_name)
            write_run_metrics_file(log_path,R2_train,rmse_train,mae_train,R2_test,rmse_test,mae_test)
            
            # Save predictions
            save_path = os.path.join(runfolder, "predictions_%s.hdf5" %base_name)
            save_predictions(save_path,y_pred_test,y_pred_train)
            
            # Save model weight in the right folder and remote the temporary folder for the ModelCheckpoint
            weight_file = os.path.join(runfolder,'Best_checkoint_%s.hdf5' %base_name)
            shutil.move(checkpoint_filepath, weight_file)
            try:
                shutil.rmtree(os.path.split(checkpoint_filepath)[0])
            except OSError as e:
                print("Error: %s - %s." % (e.filename, e.strerror))
            
            # Plots
            plot_loss(history, os.path.join(runfolder,"Loss_MSE_%s.png" %base_name), show=False)
            plot_pred_train(y_train, y_pred_train, R2_train, rmse_train, mae_train, os.path.join(runfolder,"mae_train_%s.png" %base_name), show=False)
            plot_pred_test(y_test, y_pred_test, R2_test, rmse_test, mae_test, os.path.join(runfolder,"mae_test_%s.png" %base_name), show=False)
            
            # Add metrics of the run to the summary table
            run_metrics = pd.Series([i,runfolder,weight_file,training_time,len(history.history['loss']),R2_train,rmse_train,mae_train,R2_test,rmse_test,mae_test], index=mutlirun_table.columns)
            mutlirun_table = mutlirun_table.append(run_metrics, ignore_index=True)
            
        # Create and save the plot loss of multirun
        plot_loss_multirun(mutlirun_instance.multirun_histories, os.path.join(self.outputfolder,'multirun_plot.png'), show=False)
        # Sort the summary table with R2_test descending and save the table to the mutlirun folder
        mutlirun_table.sort_values("R2_test", ascending=False, inplace=True)
        mutlirun_table.reset_index(inplace=True)
        mutlirun_table.to_csv(os.path.join(self.outputfolder,'multirun_table.csv'), index=False)
        self.mutlirun_table = mutlirun_table
        # Compute mean and standard deviation of the runs
        mutlirun_summary = pd.DataFrame()
        mutlirun_summary['Mean'] = mutlirun_table.loc[:, ~mutlirun_table.columns.isin(['Run','Run_dir','Weight_file'])].mean()
        mutlirun_summary['Std'] = mutlirun_table.loc[:, ~mutlirun_table.columns.isin(['Run','Run_di','weight_file'])].std()
        mutlirun_summary.to_csv(os.path.join(self.outputfolder,'multirun_summary.csv'), index=False)
        self.mutlirun_summary = mutlirun_summary
        ## Print processing time
        print_processing_time(starttime ,"Multirun process achieved in ")

# %%
class mutli_run_cv():
    
    def __init__(self, kf_train, kf_val, lr, earlypatience, reduceplateau, bsize, nb_epochs, datagen, outputfolder):
        self.kf_train = kf_train
        self.kf_val = kf_val
        self.lr = lr
        self.earlypatience = earlypatience
        self.reduceplateau = reduceplateau
        self.bsize = bsize
        self.nb_epochs = nb_epochs
        self.datagen = datagen
        self.outputfolder = outputfolder

    def run(self):        
        # Save current time for time management
        starttime = start_processing()
        # Create folder for the multirun 
        check_create_dir(self.outputfolder)
        # Create a table (pandas dataframe) to store the multiple run values
        mutlirun_table = pd.DataFrame(columns = ["Run", "Run_dir", "Weight_file", "RunTime", "Epochs", 
                                                 "R2_train", "rmse_train", "mae_train", 
                                                 "R2_val", "rmse_val", "mae_val"],dtype=object)
        # Create a list of history
        multirun_histories = []
        self.multirun_histories = multirun_histories
        # Create a MirroredStrategy.
        strategy = tf.distribute.MirroredStrategy()
        print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
        # Mutlirun with K-fold cross validation 
        fold_no = 1
        for train_index, val_index in zip(self.kf_train,self.kf_val):
            # Clear session to avoid increasing the memory usage after each loop
            tf.keras.backend.clear_session()
            # Clear the output of the previous loop
            clear_output(wait=True)
            # Print current loop number
            print("\nStarting fold {}/{}...".format(fold_no,len(self.kf_train)))
            # Save current time for time management
            starttime = time.time()
            
            # Select the current train/val fold 
            x_train = stack[list(train_index),:,:,:]  #Training images
            y_train = scores[list(train_index)]  #Training labels
            x_val = stack[list(val_index),:,:,:]  #Validation images
            y_val = scores[list(val_index)]  #Validation labels
            
            # Define callbacks for this run (needed to reinitialise at least the checkpoint from the previous run)
            checkpoint_filepath = os.path.join(tempfile.mkdtemp(),'Best_performed_model.hdf5')
            checkpoint = ModelCheckpoint(checkpoint_filepath, monitor='val_mean_absolute_error', verbose=1, save_best_only=True, mode='min')
            tmp_csv_path = os.path.join(tempfile.gettempdir(), "run_log.csv")
            csv_logger = tf.keras.callbacks.CSVLogger(tmp_csv_path, separator=";", append=True)
            callbacklist = [checkpoint, csv_logger]
            if self.reduceplateau:
                reduce = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=self.reduceplateau, verbose=1, mode='auto', cooldown=0, min_lr=0)
                callbacklist.append(reduce)
            if self.earlypatience:
                early = EarlyStopping(monitor="val_loss",mode="min",patience=self.earlypatience) # probably needs to be more patient
                callbacklist.append(early)  
                
            # Open a strategy scope.
            with strategy.scope():
                # Create a new instance of the model
                model = VGG_model()
                # Optimizer and learning rate    
                opt = Adam(learning_rate=self.lr)
                # Compile the model with LOSS, Optimizer, metrics
                model.compile(loss="mean_squared_error", optimizer=opt, metrics=['mean_absolute_error','RootMeanSquaredError',coeff_determination]) 
              
            # Train the model 
            history = model.fit(self.datagen.flow(x_train, y_train, batch_size=self.bsize, shuffle=False, seed=3),
                                steps_per_epoch=int(len(x_train)/self.bsize),
                                validation_data = (x_val,y_val),
                                epochs = self.nb_epochs, 
                                callbacks = callbacklist
                                )
            # Save processing time
            training_time = round((time.time() - starttime)/60,1)
            
            # Append the run history to the multirun_hostories list
            multirun_histories.append(history)
            
            # Load the weights from the best checkpoint
            model.load_weights(checkpoint_filepath)
            # run the model on the train val and test datasets 
            y_pred_train = model.predict(x_train)
            y_pred_val = model.predict(x_val) 

            # Calculate the R2 Score and RMSE
            R2_train = r2_score(y_train, y_pred_train)
            rmse_train = mean_squared_error(y_train, y_pred_train,squared=False) 
            mae_train = mean_absolute_error(y_train, y_pred_train)
            R2_val = r2_score(y_val,y_pred_val)
            rmse_val = mean_squared_error(y_val, y_pred_val,squared=False) 
            mae_val = mean_absolute_error(y_val, y_pred_val)

            # Create folder for this run 
            base_name = "kf_%s_train_%0.2f_val_%0.2f" %(fold_no,R2_train,R2_val)
            runfolder = os.path.join(self.outputfolder, base_name)
            check_create_dir(runfolder)

            # Move tmp LOGGER files to run directory
            shutil.move(tmp_csv_path, os.path.join(runfolder, "run_log.txt"))
            
            # Write metrics on the run log file
            log_path = os.path.join(runfolder, "run_metrics_%s.txt" %base_name)
            write_run_metrics_file(log_path,R2_train,rmse_train,mae_train,R2_val,rmse_val,mae_val)
            
            # Save predictions
            save_path = os.path.join(runfolder, "predictions_%s.hdf5" %base_name)
            save_predictions(save_path,y_pred_val,y_pred_train)
            
            # Save model weight in the right folder and remote the temporary folder for the ModelCheckpoint
            weight_file = os.path.join(runfolder,'Best_checkoint_%s.hdf5' %base_name)
            shutil.move(checkpoint_filepath, weight_file)
            try:
                shutil.rmtree(os.path.split(checkpoint_filepath)[0])
            except OSError as e:
                print("Error: %s - %s." % (e.filename, e.strerror))
            
            # Plots
            plot_loss(history, os.path.join(runfolder,"Loss_MSE_%s.png" %base_name), show=False)
            plot_pred_train(y_train, y_pred_train, R2_train, rmse_train, mae_train, os.path.join(runfolder,"mae_train_%s.png" %base_name), show=False)
            plot_pred_test(y_val, y_pred_val, R2_val, rmse_val, mae_val, os.path.join(runfolder,"mae_val_%s.png" %base_name), show=False)
            
            # Add metrics of the run to the summary table
            run_metrics = pd.Series([fold_no,runfolder,weight_file,training_time,len(history.history['loss']),
                                     R2_train,rmse_train,mae_train,
                                     R2_val,rmse_val,mae_val], index=mutlirun_table.columns)
            mutlirun_table = mutlirun_table.append(run_metrics, ignore_index=True)
            
            # Increase fold number
            fold_no = fold_no + 1
    
        # Create and save the plot loss of multirun
        plot_loss_multirun(mutlirun_instance.multirun_histories, os.path.join(self.outputfolder,'multirun_plot.png'), show=False)
        # Sort the summary table with R2_val descending and save the table to the mutlirun folder
        mutlirun_table.sort_values("R2_val", ascending=False, inplace=True)
        mutlirun_table.reset_index(inplace=True)
        mutlirun_table.to_csv(os.path.join(self.outputfolder,'multirun_table.csv'), index=False)
        self.mutlirun_table = mutlirun_table
        # Compute mean and standard deviation of the runs
        mutlirun_summary = pd.DataFrame()
        mutlirun_summary['Mean'] = mutlirun_table.loc[:, ~mutlirun_table.columns.isin(['Run','Run_dir','Weight_file'])].mean()
        mutlirun_summary['Std'] = mutlirun_table.loc[:, ~mutlirun_table.columns.isin(['Run','Run_di','weight_file'])].std()
        mutlirun_summary.to_csv(os.path.join(self.outputfolder,'multirun_summary.csv'), index=False)
        self.mutlirun_summary = mutlirun_summary
        ## Print processing time
        print_processing_time(starttime ,"Multirun process achieved in ")

# %% [markdown]
# # 3 Train model

# %% [markdown]
# ## 3.1 K-Fold cross-validation

# %%
# Define hyperparameter
bsize = 128
nb_epochs = 400
early_patience = False
reduceplateau = False
datagen = ImageDataGenerator() # Set Image Data Generator

# %%
multirun_dir = os.path.join(output_path,"results_mutlirun_%sepochs_%sbsize_Early%s" %(nb_epochs,bsize,early_patience))
mutlirun_instance = mutli_run_cv(idx_train, idx_val, 1e-3, early_patience, reduceplateau, bsize, nb_epochs, datagen, multirun_dir)

# %%
mutlirun_instance.run()
# Out:
# Starting fold 2/10...
# WARNING:tensorflow:Using MirroredStrategy eagerly has significant overhead currently. We will be working on improving this in the future, but for now please wrap `call_for_each_replica` or `experimental_run` or `run` inside a tf.function to get the best performance.
# Epoch 1/400
# INFO:tensorflow:batch_all_reduce: 38 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 38 all-reduces with algorithm = nccl, num_packs = 1
# 14/14 [==============================] - ETA: 0s - loss: 621.1703 - mean_absolute_error: 24.8380 - root_mean_squared_error: 24.9238 - coeff_determination: -586.9503
# Epoch 1: val_mean_absolute_error improved from inf to 25.57638, saving model to /tmp/tmpy1ne7r_d/Best_performed_model.hdf5
# 14/14 [==============================] - 19s 226ms/step - loss: 621.1703 - mean_absolute_error: 24.8380 - root_mean_squared_error: 24.9238 - coeff_determination: -586.9503 - val_loss: 657.5500 - val_mean_absolute_error: 25.5764 - val_root_mean_squared_error: 25.6428 - val_coeff_determination: -481.3058
# Epoch 2/400
# 14/14 [==============================] - ETA: 0s - loss: 551.0677 - mean_absolute_error: 23.3760 - root_mean_squared_error: 23.4738 - coeff_determination: -516.4703
# Epoch 2: val_mean_absolute_error improved from 25.57638 to 25.28370, saving model to /tmp/tmpy1ne7r_d/Best_performed_model.hdf5
# 14/14 [==============================] - 2s 161ms/step - loss: 551.0677 - mean_absolute_error: 23.3760 - root_mean_squared_error: 23.4738 - coeff_determination: -516.4703 - val_loss: 644.7800 - val_mean_absolute_error: 25.2837 - val_root_mean_squared_error: 25.3924 - val_coeff_determination: -485.1037
# Epoch 3/400
# 14/14 [==============================] - ETA: 0s - loss: 464.2057 - mean_absolute_error: 21.4147 - root_mean_squared_error: 21.5450 - coeff_determination: -433.5075
# Epoch 3: val_mean_absolute_error improved from 25.28370 to 23.47640, saving model to /tmp/tmpy1ne7r_d/Best_performed_model.hdf5
# 14/14 [==============================] - 2s 160ms/step - loss: 464.2057 - mean_absolute_error: 21.4147 - root_mean_squared_error: 21.5450 - coeff_determination: -433.5075 - val_loss: 554.6100 - val_mean_absolute_error: 23.4764 - val_root_mean_squared_error: 23.5489 - val_coeff_determination: -407.7103
# Epoch 4/400
# 14/14 [==============================] - ETA: 0s - loss: 394.7665 - mean_absolute_error: 19.7236 - root_mean_squared_error: 19.8689 - coeff_determination: -386.7534
# Epoch 4: val_mean_absolute_error improved from 23.47640 to 22.03228, saving model to /tmp/tmpy1ne7r_d/Best_performed_model.hdf5
# 14/14 [==============================] - 2s 152ms/step - loss: 394.7665 - mean_absolute_error: 19.7236 - root_mean_squared_error: 19.8689 - coeff_determination: -386.7534 - val_loss: 488.5100 - val_mean_absolute_error: 22.0323 - val_root_mean_squared_error: 22.1018 - val_coeff_determination: -353.4749
# Epoch 5/400
# 14/14 [==============================] - ETA: 0s - loss: 331.1578 - mean_absolute_error: 18.0418 - root_mean_squared_error: 18.1976 - coeff_determination: -322.0862
# Epoch 5: val_mean_absolute_error improved from 22.03228 to 21.49722, saving model to /tmp/tmpy1ne7r_d/Best_performed_model.hdf5
# 14/14 [==============================] - 2s 157ms/step - loss: 331.1578 - mean_absolute_error: 18.0418 - root_mean_squared_error: 18.1976 - coeff_determination: -322.0862 - val_loss: 465.0300 - val_mean_absolute_error: 21.4972 - val_root_mean_squared_error: 21.5646 - val_coeff_determination: -331.3979
# Epoch 6/400
# 14/14 [==============================] - ETA: 0s - loss: 270.9777 - mean_absolute_error: 16.2694 - root_mean_squared_error: 16.4606 - coeff_determination: -263.6348
# Epoch 6: val_mean_absolute_error improved from 21.49722 to 20.56224, saving model to /tmp/tmpy1ne7r_d/Best_performed_model.hdf5
# 14/14 [==============================] - 2s 154ms/step - loss: 270.9777 - mean_absolute_error: 16.2694 - root_mean_squared_error: 16.4606 - coeff_determination: -263.6348 - val_loss: 426.2100 - val_mean_absolute_error: 20.5622 - val_root_mean_squared_error: 20.6439 - val_coeff_determination: -308.7212
# Epoch 7/400
# 14/14 [==============================] - ETA: 0s - loss: 213.2460 - mean_absolute_error: 14.3673 - root_mean_squared_error: 14.6026 - coeff_determination: -209.0473
# Epoch 7: val_mean_absolute_error improved from 20.56224 to 18.63041, saving model to /tmp/tmpy1ne7r_d/Best_performed_model.hdf5
# 14/14 [==============================] - 2s 158ms/step - loss: 213.2460 - mean_absolute_error: 14.3673 - root_mean_squared_error: 14.6026 - coeff_determination: -209.0473 - val_loss: 351.6850 - val_mean_absolute_error: 18.6304 - val_root_mean_squared_error: 18.7534 - val_coeff_determination: -262.1665
# Epoch 8/400
# 14/14 [==============================] - ETA: 0s - loss: 166.3049 - mean_absolute_error: 12.6316 - root_mean_squared_error: 12.8961 - coeff_determination: -167.7990
# Epoch 8: val_mean_absolute_error improved from 18.63041 to 17.63277, saving model to /tmp/tmpy1ne7r_d/Best_performed_model.hdf5
# 14/14 [==============================] - 2s 151ms/step - loss: 166.3049 - mean_absolute_error: 12.6316 - root_mean_squared_error: 12.8961 - coeff_determination: -167.7990 - val_loss: 317.3300 - val_mean_absolute_error: 17.6328 - val_root_mean_squared_error: 17.8143 - val_coeff_determination: -238.6991
# Epoch 9/400
# 14/14 [==============================] - ETA: 0s - loss: 127.4417 - mean_absolute_error: 10.9871 - root_mean_squared_error: 11.2893 - coeff_determination: -125.0443
# Epoch 9: val_mean_absolute_error improved from 17.63277 to 13.66725, saving model to /tmp/tmpy1ne7r_d/Best_performed_model.hdf5
# 14/14 [==============================] - 2s 159ms/step - loss: 127.4417 - mean_absolute_error: 10.9871 - root_mean_squared_error: 11.2893 - coeff_determination: -125.0443 - val_loss: 198.4400 - val_mean_absolute_error: 13.6672 - val_root_mean_squared_error: 14.0867 - val_coeff_determination: -161.5246
# Epoch 10/400
# 14/14 [==============================] - ETA: 0s - loss: 92.0235 - mean_absolute_error: 9.2146 - root_mean_squared_error: 9.5930 - coeff_determination: -75.3266
# Epoch 10: val_mean_absolute_error did not improve from 13.66725
# 14/14 [==============================] - 2s 117ms/step - loss: 92.0235 - mean_absolute_error: 9.2146 - root_mean_squared_error: 9.5930 - coeff_determination: -75.3266 - val_loss: 248.4300 - val_mean_absolute_error: 15.5765 - val_root_mean_squared_error: 15.7622 - val_coeff_determination: -186.8932
# Epoch 11/400
# 14/14 [==============================] - ETA: 0s - loss: 65.2808 - mean_absolute_error: 7.6013 - root_mean_squared_error: 8.0796 - coeff_determination: -66.2260
# Epoch 11: val_mean_absolute_error did not improve from 13.66725
# 14/14 [==============================] - 2s 119ms/step - loss: 65.2808 - mean_absolute_error: 7.6013 - root_mean_squared_error: 8.0796 - coeff_determination: -66.2260 - val_loss: 221.0850 - val_mean_absolute_error: 14.6193 - val_root_mean_squared_error: 14.8684 - val_coeff_determination: -172.5632
# Epoch 12/400
# 14/14 [==============================] - ETA: 0s - loss: 46.4597 - mean_absolute_error: 6.2606 - root_mean_squared_error: 6.8160 - coeff_determination: -39.2748
# Epoch 12: val_mean_absolute_error improved from 13.66725 to 10.35566, saving model to /tmp/tmpy1ne7r_d/Best_performed_model.hdf5
# 14/14 [==============================] - 2s 157ms/step - loss: 46.4597 - mean_absolute_error: 6.2606 - root_mean_squared_error: 6.8160 - coeff_determination: -39.2748 - val_loss: 129.3387 - val_mean_absolute_error: 10.3557 - val_root_mean_squared_error: 11.3726 - val_coeff_determination: -112.0942
# Epoch 13/400
# 14/14 [==============================] - ETA: 0s - loss: 31.7713 - mean_absolute_error: 4.9770 - root_mean_squared_error: 5.6368 - coeff_determination: -29.0165
# Epoch 13: val_mean_absolute_error did not improve from 10.35566
# 14/14 [==============================] - 2s 121ms/step - loss: 31.7713 - mean_absolute_error: 4.9770 - root_mean_squared_error: 5.6368 - coeff_determination: -29.0165 - val_loss: 163.1800 - val_mean_absolute_error: 12.3818 - val_root_mean_squared_error: 12.7746 - val_coeff_determination: -128.2013
# Epoch 14/400
# 14/14 [==============================] - ETA: 0s - loss: 22.0052 - mean_absolute_error: 4.0209 - root_mean_squared_error: 4.6909 - coeff_determination: -15.5845
# Epoch 14: val_mean_absolute_error did not improve from 10.35566
# 14/14 [==============================] - 2s 119ms/step - loss: 22.0052 - mean_absolute_error: 4.0209 - root_mean_squared_error: 4.6909 - coeff_determination: -15.5845 - val_loss: 178.9950 - val_mean_absolute_error: 13.2463 - val_root_mean_squared_error: 13.3787 - val_coeff_determination: -129.3408
# Epoch 15/400
# 14/14 [==============================] - ETA: 0s - loss: 16.0895 - mean_absolute_error: 3.3592 - root_mean_squared_error: 4.0112 - coeff_determination: -10.9629
# Epoch 15: val_mean_absolute_error did not improve from 10.35566
# 14/14 [==============================] - 2s 119ms/step - loss: 16.0895 - mean_absolute_error: 3.3592 - root_mean_squared_error: 4.0112 - coeff_determination: -10.9629 - val_loss: 176.7100 - val_mean_absolute_error: 13.1683 - val_root_mean_squared_error: 13.2934 - val_coeff_determination: -133.5965
# Epoch 16/400
# 14/14 [==============================] - ETA: 0s - loss: 12.2328 - mean_absolute_error: 2.8538 - root_mean_squared_error: 3.4974 - coeff_determination: -10.7726
# Epoch 16: val_mean_absolute_error did not improve from 10.35566
# 14/14 [==============================] - 2s 120ms/step - loss: 12.2328 - mean_absolute_error: 2.8538 - root_mean_squared_error: 3.4974 - coeff_determination: -10.7726 - val_loss: 147.9325 - val_mean_absolute_error: 11.9402 - val_root_mean_squared_error: 12.1631 - val_coeff_determination: -103.4368
# Epoch 17/400
# 14/14 [==============================] - ETA: 0s - loss: 11.0127 - mean_absolute_error: 2.6644 - root_mean_squared_error: 3.3185 - coeff_determination: -11.4277
# Epoch 17: val_mean_absolute_error did not improve from 10.35566
# 14/14 [==============================] - 2s 120ms/step - loss: 11.0127 - mean_absolute_error: 2.6644 - root_mean_squared_error: 3.3185 - coeff_determination: -11.4277 - val_loss: 136.9900 - val_mean_absolute_error: 11.4904 - val_root_mean_squared_error: 11.7041 - val_coeff_determination: -97.0588
# Epoch 18/400
# 14/14 [==============================] - ETA: 0s - loss: 9.5514 - mean_absolute_error: 2.5185 - root_mean_squared_error: 3.0906 - coeff_determination: -6.6903
# Epoch 18: val_mean_absolute_error did not improve from 10.35566
# 14/14 [==============================] - 2s 119ms/step - loss: 9.5514 - mean_absolute_error: 2.5185 - root_mean_squared_error: 3.0906 - coeff_determination: -6.6903 - val_loss: 116.2325 - val_mean_absolute_error: 10.5312 - val_root_mean_squared_error: 10.7812 - val_coeff_determination: -79.8218
# Epoch 19/400
# 14/14 [==============================] - ETA: 0s - loss: 8.7968 - mean_absolute_error: 2.3747 - root_mean_squared_error: 2.9660 - coeff_determination: -6.9967
# Epoch 19: val_mean_absolute_error improved from 10.35566 to 10.05996, saving model to /tmp/tmpy1ne7r_d/Best_performed_model.hdf5
# 14/14 [==============================] - 2s 152ms/step - loss: 8.7968 - mean_absolute_error: 2.3747 - root_mean_squared_error: 2.9660 - coeff_determination: -6.9967 - val_loss: 105.1525 - val_mean_absolute_error: 10.0600 - val_root_mean_squared_error: 10.2545 - val_coeff_determination: -75.2070
# Epoch 20/400
# 14/14 [==============================] - ETA: 0s - loss: 8.8789 - mean_absolute_error: 2.4026 - root_mean_squared_error: 2.9798 - coeff_determination: -4.1962
# Epoch 20: val_mean_absolute_error improved from 10.05996 to 9.65344, saving model to /tmp/tmpy1ne7r_d/Best_performed_model.hdf5
# 14/14 [==============================] - 2s 162ms/step - loss: 8.8789 - mean_absolute_error: 2.4026 - root_mean_squared_error: 2.9798 - coeff_determination: -4.1962 - val_loss: 97.9925 - val_mean_absolute_error: 9.6534 - val_root_mean_squared_error: 9.8993 - val_coeff_determination: -67.9572
# Epoch 21/400
# 14/14 [==============================] - ETA: 0s - loss: 8.8378 - mean_absolute_error: 2.3933 - root_mean_squared_error: 2.9728 - coeff_determination: -8.5228
# Epoch 21: val_mean_absolute_error improved from 9.65344 to 8.62297, saving model to /tmp/tmpy1ne7r_d/Best_performed_model.hdf5
# 14/14 [==============================] - 2s 160ms/step - loss: 8.8378 - mean_absolute_error: 2.3933 - root_mean_squared_error: 2.9728 - coeff_determination: -8.5228 - val_loss: 81.2781 - val_mean_absolute_error: 8.6230 - val_root_mean_squared_error: 9.0154 - val_coeff_determination: -51.1033
# Epoch 22/400
# 14/14 [==============================] - ETA: 0s - loss: 8.5383 - mean_absolute_error: 2.3460 - root_mean_squared_error: 2.9222 - coeff_determination: -4.1049
# Epoch 22: val_mean_absolute_error did not improve from 8.62297
# 14/14 [==============================] - 2s 119ms/step - loss: 8.5383 - mean_absolute_error: 2.3460 - root_mean_squared_error: 2.9222 - coeff_determination: -4.1049 - val_loss: 93.6000 - val_mean_absolute_error: 9.4297 - val_root_mean_squared_error: 9.6748 - val_coeff_determination: -64.8462
# Epoch 23/400
# 14/14 [==============================] - ETA: 0s - loss: 8.7746 - mean_absolute_error: 2.3864 - root_mean_squared_error: 2.9621 - coeff_determination: -4.6537
# Epoch 23: val_mean_absolute_error did not improve from 8.62297
# 14/14 [==============================] - 2s 118ms/step - loss: 8.7746 - mean_absolute_error: 2.3864 - root_mean_squared_error: 2.9621 - coeff_determination: -4.6537 - val_loss: 81.8962 - val_mean_absolute_error: 8.7578 - val_root_mean_squared_error: 9.0495 - val_coeff_determination: -52.7273
# Epoch 24/400
# 14/14 [==============================] - ETA: 0s - loss: 7.8917 - mean_absolute_error: 2.2425 - root_mean_squared_error: 2.8094 - coeff_determination: -4.3212
# Epoch 24: val_mean_absolute_error did not improve from 8.62297
# 14/14 [==============================] - 2s 120ms/step - loss: 7.8917 - mean_absolute_error: 2.2425 - root_mean_squared_error: 2.8094 - coeff_determination: -4.3212 - val_loss: 90.6637 - val_mean_absolute_error: 9.3300 - val_root_mean_squared_error: 9.5209 - val_coeff_determination: -64.5444
# Epoch 25/400
# 14/14 [==============================] - ETA: 0s - loss: 7.7730 - mean_absolute_error: 2.2123 - root_mean_squared_error: 2.7880 - coeff_determination: -6.3502
# Epoch 25: val_mean_absolute_error did not improve from 8.62297
# 14/14 [==============================] - 2s 119ms/step - loss: 7.7730 - mean_absolute_error: 2.2123 - root_mean_squared_error: 2.7880 - coeff_determination: -6.3502 - val_loss: 93.2025 - val_mean_absolute_error: 9.4924 - val_root_mean_squared_error: 9.6543 - val_coeff_determination: -71.1216
# Epoch 26/400
# 14/14 [==============================] - ETA: 0s - loss: 7.3332 - mean_absolute_error: 2.1443 - root_mean_squared_error: 2.7079 - coeff_determination: -2.8390
# Epoch 26: val_mean_absolute_error did not improve from 8.62297
# 14/14 [==============================] - 2s 119ms/step - loss: 7.3332 - mean_absolute_error: 2.1443 - root_mean_squared_error: 2.7079 - coeff_determination: -2.8390 - val_loss: 80.0863 - val_mean_absolute_error: 8.7690 - val_root_mean_squared_error: 8.9492 - val_coeff_determination: -60.5312
# Epoch 27/400
# 14/14 [==============================] - ETA: 0s - loss: 7.2896 - mean_absolute_error: 2.1794 - root_mean_squared_error: 2.6999 - coeff_determination: -4.8272
# Epoch 27: val_mean_absolute_error did not improve from 8.62297
# 14/14 [==============================] - 2s 120ms/step - loss: 7.2896 - mean_absolute_error: 2.1794 - root_mean_squared_error: 2.6999 - coeff_determination: -4.8272 - val_loss: 89.2962 - val_mean_absolute_error: 9.2995 - val_root_mean_squared_error: 9.4498 - val_coeff_determination: -68.2691
# Epoch 28/400
# 14/14 [==============================] - ETA: 0s - loss: 7.7695 - mean_absolute_error: 2.2235 - root_mean_squared_error: 2.7873 - coeff_determination: -4.6316
# Epoch 28: val_mean_absolute_error improved from 8.62297 to 6.04906, saving model to /tmp/tmpy1ne7r_d/Best_performed_model.hdf5
# 14/14 [==============================] - 2s 154ms/step - loss: 7.7695 - mean_absolute_error: 2.2235 - root_mean_squared_error: 2.7873 - coeff_determination: -4.6316 - val_loss: 48.1325 - val_mean_absolute_error: 6.0491 - val_root_mean_squared_error: 6.9376 - val_coeff_determination: -27.5296
# Epoch 29/400
# 14/14 [==============================] - ETA: 0s - loss: 8.0353 - mean_absolute_error: 2.2597 - root_mean_squared_error: 2.8346 - coeff_determination: -5.2073
# Epoch 29: val_mean_absolute_error did not improve from 6.04906
# 14/14 [==============================] - 2s 120ms/step - loss: 8.0353 - mean_absolute_error: 2.2597 - root_mean_squared_error: 2.8346 - coeff_determination: -5.2073 - val_loss: 60.2188 - val_mean_absolute_error: 7.0168 - val_root_mean_squared_error: 7.7599 - val_coeff_determination: -38.2900
# Epoch 30/400
# 14/14 [==============================] - ETA: 0s - loss: 7.7886 - mean_absolute_error: 2.2517 - root_mean_squared_error: 2.7908 - coeff_determination: -3.7140
# Epoch 30: val_mean_absolute_error did not improve from 6.04906
# 14/14 [==============================] - 2s 119ms/step - loss: 7.7886 - mean_absolute_error: 2.2517 - root_mean_squared_error: 2.7908 - coeff_determination: -3.7140 - val_loss: 78.1212 - val_mean_absolute_error: 8.5789 - val_root_mean_squared_error: 8.8381 - val_coeff_determination: -53.7919
# Epoch 31/400
# 14/14 [==============================] - ETA: 0s - loss: 7.7806 - mean_absolute_error: 2.2308 - root_mean_squared_error: 2.7894 - coeff_determination: -5.7807
# Epoch 31: val_mean_absolute_error did not improve from 6.04906
# 14/14 [==============================] - 2s 119ms/step - loss: 7.7806 - mean_absolute_error: 2.2308 - root_mean_squared_error: 2.7894 - coeff_determination: -5.7807 - val_loss: 57.9944 - val_mean_absolute_error: 7.2704 - val_root_mean_squared_error: 7.6152 - val_coeff_determination: -40.2014
# Epoch 32/400
# 14/14 [==============================] - ETA: 0s - loss: 8.0268 - mean_absolute_error: 2.2545 - root_mean_squared_error: 2.8331 - coeff_determination: -12.8592
# Epoch 32: val_mean_absolute_error did not improve from 6.04906
# 14/14 [==============================] - 2s 120ms/step - loss: 8.0268 - mean_absolute_error: 2.2545 - root_mean_squared_error: 2.8331 - coeff_determination: -12.8592 - val_loss: 81.3050 - val_mean_absolute_error: 8.7685 - val_root_mean_squared_error: 9.0168 - val_coeff_determination: -60.3941
# Epoch 33/400
# 14/14 [==============================] - ETA: 0s - loss: 7.9687 - mean_absolute_error: 2.2545 - root_mean_squared_error: 2.8230 - coeff_determination: -5.6377
# Epoch 33: val_mean_absolute_error did not improve from 6.04906
# 14/14 [==============================] - 2s 119ms/step - loss: 7.9687 - mean_absolute_error: 2.2545 - root_mean_squared_error: 2.8230 - coeff_determination: -5.6377 - val_loss: 67.0456 - val_mean_absolute_error: 6.5584 - val_root_mean_squared_error: 8.1878 - val_coeff_determination: -39.8993
# Epoch 34/400
# 14/14 [==============================] - ETA: 0s - loss: 9.9769 - mean_absolute_error: 2.5144 - root_mean_squared_error: 3.1586 - coeff_determination: -9.5819
# Epoch 34: val_mean_absolute_error did not improve from 6.04906
# 14/14 [==============================] - 2s 119ms/step - loss: 9.9769 - mean_absolute_error: 2.5144 - root_mean_squared_error: 3.1586 - coeff_determination: -9.5819 - val_loss: 80.2791 - val_mean_absolute_error: 7.2378 - val_root_mean_squared_error: 8.9600 - val_coeff_determination: -46.0518
# Epoch 35/400
# 14/14 [==============================] - ETA: 0s - loss: 9.1219 - mean_absolute_error: 2.4171 - root_mean_squared_error: 3.0203 - coeff_determination: -5.4152
# Epoch 35: val_mean_absolute_error did not improve from 6.04906
# 14/14 [==============================] - 2s 123ms/step - loss: 9.1219 - mean_absolute_error: 2.4171 - root_mean_squared_error: 3.0203 - coeff_determination: -5.4152 - val_loss: 52.3920 - val_mean_absolute_error: 6.1082 - val_root_mean_squared_error: 7.2379 - val_coeff_determination: -29.7919
# Epoch 36/400
# 14/14 [==============================] - ETA: 0s - loss: 8.3159 - mean_absolute_error: 2.2986 - root_mean_squared_error: 2.8838 - coeff_determination: -3.9707
# Epoch 36: val_mean_absolute_error did not improve from 6.04906
# 14/14 [==============================] - 2s 120ms/step - loss: 8.3159 - mean_absolute_error: 2.2986 - root_mean_squared_error: 2.8838 - coeff_determination: -3.9707 - val_loss: 66.7175 - val_mean_absolute_error: 7.7004 - val_root_mean_squared_error: 8.1677 - val_coeff_determination: -46.1910
# Epoch 37/400
# 14/14 [==============================] - ETA: 0s - loss: 7.8814 - mean_absolute_error: 2.2517 - root_mean_squared_error: 2.8074 - coeff_determination: -4.1816
# Epoch 37: val_mean_absolute_error did not improve from 6.04906
# 14/14 [==============================] - 2s 119ms/step - loss: 7.8814 - mean_absolute_error: 2.2517 - root_mean_squared_error: 2.8074 - coeff_determination: -4.1816 - val_loss: 77.3650 - val_mean_absolute_error: 8.4970 - val_root_mean_squared_error: 8.7958 - val_coeff_determination: -61.5598
# Epoch 38/400
# 14/14 [==============================] - ETA: 0s - loss: 7.4594 - mean_absolute_error: 2.1542 - root_mean_squared_error: 2.7312 - coeff_determination: -2.8418
# Epoch 38: val_mean_absolute_error did not improve from 6.04906
# 14/14 [==============================] - 2s 119ms/step - loss: 7.4594 - mean_absolute_error: 2.1542 - root_mean_squared_error: 2.7312 - coeff_determination: -2.8418 - val_loss: 63.0225 - val_mean_absolute_error: 7.6750 - val_root_mean_squared_error: 7.9389 - val_coeff_determination: -50.5943
# Epoch 39/400
# 14/14 [==============================] - ETA: 0s - loss: 7.5093 - mean_absolute_error: 2.1533 - root_mean_squared_error: 2.7403 - coeff_determination: -3.1372
# Epoch 39: val_mean_absolute_error did not improve from 6.04906
# 14/14 [==============================] - 2s 122ms/step - loss: 7.5093 - mean_absolute_error: 2.1533 - root_mean_squared_error: 2.7403 - coeff_determination: -3.1372 - val_loss: 60.7412 - val_mean_absolute_error: 7.5155 - val_root_mean_squared_error: 7.7938 - val_coeff_determination: -48.9860
# Epoch 40/400
# 14/14 [==============================] - ETA: 0s - loss: 6.8841 - mean_absolute_error: 2.0758 - root_mean_squared_error: 2.6238 - coeff_determination: -4.1783
# Epoch 40: val_mean_absolute_error did not improve from 6.04906
# 14/14 [==============================] - 2s 121ms/step - loss: 6.8841 - mean_absolute_error: 2.0758 - root_mean_squared_error: 2.6238 - coeff_determination: -4.1783 - val_loss: 59.5187 - val_mean_absolute_error: 7.3663 - val_root_mean_squared_error: 7.7147 - val_coeff_determination: -46.3123
# Epoch 41/400
# 14/14 [==============================] - ETA: 0s - loss: 7.4549 - mean_absolute_error: 2.1911 - root_mean_squared_error: 2.7304 - coeff_determination: -3.6345
# Epoch 41: val_mean_absolute_error did not improve from 6.04906
# 14/14 [==============================] - 2s 120ms/step - loss: 7.4549 - mean_absolute_error: 2.1911 - root_mean_squared_error: 2.7304 - coeff_determination: -3.6345 - val_loss: 45.4969 - val_mean_absolute_error: 6.2724 - val_root_mean_squared_error: 6.7453 - val_coeff_determination: -35.7997
# Epoch 42/400
# 14/14 [==============================] - ETA: 0s - loss: 7.6498 - mean_absolute_error: 2.2215 - root_mean_squared_error: 2.7658 - coeff_determination: -8.8978
# Epoch 42: val_mean_absolute_error did not improve from 6.04906
# 14/14 [==============================] - 3s 185ms/step - loss: 7.6498 - mean_absolute_error: 2.2215 - root_mean_squared_error: 2.7658 - coeff_determination: -8.8978 - val_loss: 64.1338 - val_mean_absolute_error: 6.9561 - val_root_mean_squared_error: 8.0079 - val_coeff_determination: -49.3906
# Epoch 43/400
# 14/14 [==============================] - ETA: 0s - loss: 8.3296 - mean_absolute_error: 2.2842 - root_mean_squared_error: 2.8861 - coeff_determination: -4.5159
# Epoch 43: val_mean_absolute_error did not improve from 6.04906
# 14/14 [==============================] - 2s 118ms/step - loss: 8.3296 - mean_absolute_error: 2.2842 - root_mean_squared_error: 2.8861 - coeff_determination: -4.5159 - val_loss: 154.0475 - val_mean_absolute_error: 9.5152 - val_root_mean_squared_error: 12.4103 - val_coeff_determination: -113.7592
# Epoch 44/400
# 14/14 [==============================] - ETA: 0s - loss: 7.1741 - mean_absolute_error: 2.1214 - root_mean_squared_error: 2.6784 - coeff_determination: -4.6033
# Epoch 44: val_mean_absolute_error did not improve from 6.04906
# 14/14 [==============================] - 2s 122ms/step - loss: 7.1741 - mean_absolute_error: 2.1214 - root_mean_squared_error: 2.6784 - coeff_determination: -4.6033 - val_loss: 98.3337 - val_mean_absolute_error: 8.2072 - val_root_mean_squared_error: 9.9160 - val_coeff_determination: -81.0786
# Epoch 45/400
# 14/14 [==============================] - ETA: 0s - loss: 7.1084 - mean_absolute_error: 2.1209 - root_mean_squared_error: 2.6661 - coeff_determination: -9.6015
# Epoch 45: val_mean_absolute_error did not improve from 6.04906
# 14/14 [==============================] - 2s 122ms/step - loss: 7.1084 - mean_absolute_error: 2.1209 - root_mean_squared_error: 2.6661 - coeff_determination: -9.6015 - val_loss: 98.9837 - val_mean_absolute_error: 7.9067 - val_root_mean_squared_error: 9.9491 - val_coeff_determination: -72.6342
# Epoch 46/400
# 14/14 [==============================] - ETA: 0s - loss: 7.7414 - mean_absolute_error: 2.2208 - root_mean_squared_error: 2.7823 - coeff_determination: -3.8408
# Epoch 46: val_mean_absolute_error did not improve from 6.04906
# 14/14 [==============================] - 2s 119ms/step - loss: 7.7414 - mean_absolute_error: 2.2208 - root_mean_squared_error: 2.7823 - coeff_determination: -3.8408 - val_loss: 53.3553 - val_mean_absolute_error: 6.4410 - val_root_mean_squared_error: 7.3043 - val_coeff_determination: -37.5961
# Epoch 47/400
# 14/14 [==============================] - ETA: 0s - loss: 7.3444 - mean_absolute_error: 2.1539 - root_mean_squared_error: 2.7100 - coeff_determination: -5.2360
# Epoch 47: val_mean_absolute_error improved from 6.04906 to 5.76254, saving model to /tmp/tmpy1ne7r_d/Best_performed_model.hdf5
# 14/14 [==============================] - 2s 169ms/step - loss: 7.3444 - mean_absolute_error: 2.1539 - root_mean_squared_error: 2.7100 - coeff_determination: -5.2360 - val_loss: 42.0703 - val_mean_absolute_error: 5.7625 - val_root_mean_squared_error: 6.4862 - val_coeff_determination: -27.9771
# Epoch 48/400
# 14/14 [==============================] - ETA: 0s - loss: 7.0842 - mean_absolute_error: 2.0794 - root_mean_squared_error: 2.6617 - coeff_determination: -4.8015
# Epoch 48: val_mean_absolute_error did not improve from 5.76254
# 14/14 [==============================] - 2s 120ms/step - loss: 7.0842 - mean_absolute_error: 2.0794 - root_mean_squared_error: 2.6617 - coeff_determination: -4.8015 - val_loss: 46.3275 - val_mean_absolute_error: 5.9926 - val_root_mean_squared_error: 6.8058 - val_coeff_determination: -33.8887
# Epoch 49/400
# 14/14 [==============================] - ETA: 0s - loss: 6.5663 - mean_absolute_error: 2.0210 - root_mean_squared_error: 2.5625 - coeff_determination: -4.2327
# Epoch 49: val_mean_absolute_error did not improve from 5.76254
# 14/14 [==============================] - 2s 120ms/step - loss: 6.5663 - mean_absolute_error: 2.0210 - root_mean_squared_error: 2.5625 - coeff_determination: -4.2327 - val_loss: 49.4556 - val_mean_absolute_error: 6.1997 - val_root_mean_squared_error: 7.0327 - val_coeff_determination: -34.0106
# Epoch 50/400
# 14/14 [==============================] - ETA: 0s - loss: 7.4519 - mean_absolute_error: 2.1855 - root_mean_squared_error: 2.7298 - coeff_determination: -7.6636
# Epoch 50: val_mean_absolute_error did not improve from 5.76254
# 14/14 [==============================] - 2s 121ms/step - loss: 7.4519 - mean_absolute_error: 2.1855 - root_mean_squared_error: 2.7298 - coeff_determination: -7.6636 - val_loss: 52.1250 - val_mean_absolute_error: 6.4946 - val_root_mean_squared_error: 7.2197 - val_coeff_determination: -37.9945
# Epoch 51/400
# 14/14 [==============================] - ETA: 0s - loss: 7.6594 - mean_absolute_error: 2.1921 - root_mean_squared_error: 2.7677 - coeff_determination: -5.9448
# Epoch 51: val_mean_absolute_error did not improve from 5.76254
# 14/14 [==============================] - 2s 120ms/step - loss: 7.6594 - mean_absolute_error: 2.1921 - root_mean_squared_error: 2.7677 - coeff_determination: -5.9448 - val_loss: 61.2225 - val_mean_absolute_error: 7.1120 - val_root_mean_squared_error: 7.8245 - val_coeff_determination: -48.9122
# Epoch 52/400
# 14/14 [==============================] - ETA: 0s - loss: 7.4547 - mean_absolute_error: 2.1585 - root_mean_squared_error: 2.7303 - coeff_determination: -5.0708
# Epoch 52: val_mean_absolute_error did not improve from 5.76254
# 14/14 [==============================] - 2s 121ms/step - loss: 7.4547 - mean_absolute_error: 2.1585 - root_mean_squared_error: 2.7303 - coeff_determination: -5.0708 - val_loss: 50.8462 - val_mean_absolute_error: 6.6027 - val_root_mean_squared_error: 7.1307 - val_coeff_determination: -40.3753
# Epoch 53/400
# 14/14 [==============================] - ETA: 0s - loss: 6.9667 - mean_absolute_error: 2.1040 - root_mean_squared_error: 2.6395 - coeff_determination: -11.5365
# Epoch 53: val_mean_absolute_error did not improve from 5.76254
# 14/14 [==============================] - 2s 121ms/step - loss: 6.9667 - mean_absolute_error: 2.1040 - root_mean_squared_error: 2.6395 - coeff_determination: -11.5365 - val_loss: 50.0775 - val_mean_absolute_error: 6.6330 - val_root_mean_squared_error: 7.0767 - val_coeff_determination: -39.7598
# Epoch 54/400
# 14/14 [==============================] - ETA: 0s - loss: 7.1437 - mean_absolute_error: 2.1406 - root_mean_squared_error: 2.6727 - coeff_determination: -8.8650
# Epoch 54: val_mean_absolute_error did not improve from 5.76254
# 14/14 [==============================] - 2s 119ms/step - loss: 7.1437 - mean_absolute_error: 2.1406 - root_mean_squared_error: 2.6727 - coeff_determination: -8.8650 - val_loss: 41.5144 - val_mean_absolute_error: 6.0010 - val_root_mean_squared_error: 6.4430 - val_coeff_determination: -32.2431
# Epoch 55/400
# 14/14 [==============================] - ETA: 0s - loss: 6.7264 - mean_absolute_error: 2.0624 - root_mean_squared_error: 2.5936 - coeff_determination: -3.0275
# Epoch 55: val_mean_absolute_error did not improve from 5.76254
# 14/14 [==============================] - 2s 121ms/step - loss: 6.7264 - mean_absolute_error: 2.0624 - root_mean_squared_error: 2.5936 - coeff_determination: -3.0275 - val_loss: 40.2194 - val_mean_absolute_error: 6.0409 - val_root_mean_squared_error: 6.3420 - val_coeff_determination: -29.3842

# %%
# Print the multirun table
mutlirun_instance.mutlirun_table

# %%
# Print the multirun summary
mutlirun_instance.mutlirun_summary

# %%
img = mpimg.imread(glob.glob(os.path.join(multirun_dir,'multirun_plot*.png'))[0])
plt.figure(figsize = (25,25))
plt.axis("off")
plt.imshow(img)
plt.show()

# %% [markdown]
# # 4 Display results

# %% [markdown]
# ## 4.1 Display results of the best run

# %%
# Best run weights
multirun_best_weight = mutlirun_instance.mutlirun_table["Weight_file"][0]
multirun_best_dir = mutlirun_instance.mutlirun_table["Run_dir"][0]

# %%
img = mpimg.imread(glob.glob(os.path.join(multirun_best_dir,'Loss_MSE_*.png'))[0])
plt.figure(figsize = (25,25))
plt.axis("off")
plt.imshow(img)
plt.show()

# %%
img = mpimg.imread(glob.glob(os.path.join(multirun_best_dir,'mae_train_*.png'))[0])
plt.figure(figsize = (25,25))
plt.axis("off")
plt.imshow(img)
plt.show()

# %%
img = mpimg.imread(glob.glob(os.path.join(multirun_best_dir,'mae_val_*.png'))[0])
plt.figure(figsize = (25,25))
plt.axis("off")
plt.imshow(img)
plt.show()

# %% [markdown]
# ## 4.2 Visualize the best and worse predictions

# %%
# Load the predictions of the best run
with h5py.File(glob.glob(os.path.join(multirun_best_dir,'predictions_*.hdf5'))[0], mode="r") as f:
    y_pred_test = np.asarray(f["y_pred_test"])

# %%
multirun_best_fold = mutlirun_instance.mutlirun_table["index"][0]
x_val = stack[list(idx_val[multirun_best_fold]),:,:,:]  #Validation images
y_val = scores[list(idx_val[multirun_best_fold])]  #Validation images
val_ID = photo_id[list(idx_val[multirun_best_fold])]

# %%
# Get list of image id and corresponding Absolute Error
pred_val_score = [(x[0],x[1],x[2][0],x[3][0],x[2][0]-x[3][0],np.abs(x[2][0]-x[3][0])) for x in zip(val_ID.tolist(),x_val.tolist(),y_pred_test.tolist(),y_val.tolist())]
pred_val_score = sorted(pred_val_score, key=lambda x: x[5]) #idx0:PartimapID, idx1:Image, idx2:Ypred, idx3:Y, idx4:Error, idx5:AbsError  -- Sort by AbsError 
pred_val_score_bestworse = []
[pred_val_score_bestworse.append(x) for x in pred_val_score[:5]] #Best 
[pred_val_score_bestworse.append(x) for x in pred_val_score[-5:]] #Worse

# %%
# Visualize the best and worse predictions
plt.rcParams["figure.facecolor"] = 'w'
plt.figure(figsize=(20, 10))
for i in range(len(pred_val_score_bestworse)):
    if i<=4:
        ax = plt.subplot(2, 5, i + 1)
        plt.imshow(Norma_Xpercentile(np.array(pred_val_score_bestworse[i][1])))
        plt.axis("off")
        plt.title("Error: %0.3f\n TS-score: %0.3f \nImage n°%s"%(pred_val_score_bestworse[i][4],pred_val_score_bestworse[i][3],pred_val_score_bestworse[i][0]))
    else:
        ax = plt.subplot(2, 5, i + 1)
        plt.imshow(Norma_Xpercentile(np.array(pred_val_score_bestworse[i][1])))
        plt.axis("off")
        plt.title("Error: %0.3f\n TS-score: %0.3f \nImage n°%s"%(pred_val_score_bestworse[i][4],pred_val_score_bestworse[i][3],pred_val_score_bestworse[i][0]))
        
#plt.subplots_adjust(hspace=0.001)
plt.tight_layout() 
plt.savefig(os.path.join(results_path,'Best_Worse_Prediction.png'), dpi=300, bbox_inches='tight')
